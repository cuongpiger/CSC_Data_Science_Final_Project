# %%
# %load_ext autoreload
# %autoreload 2

# %%
import modules.utils as Utils
import pandas as pd

# %%
final_data = pd.read_csv("./data/standard_reviews.csv")

# %%
final_data
# Out:
#                                               raw_comment  \
# 0       Hàng đẹp y ảnh. Nên mua nha mọi người. Shop gi...
# 1       Đóng gói sản phẩm rất đẹp và chắc chắn. Sản ph...
# 2       Khá xinh nha các bạn, chất lượng quá tuyệt vời...
# 3       Chất lượng quá oke ngoài sức mong đợi luôn ạ q...
# 4       Vừa nhận được hàng ưng quá phải feedback ngay ...
# ...                                                   ...
# 201350  trên ảnh miếng da màu đen nhưng giao miếng da ...
# 201351  Giao hàng quá chậm. 10 ngày mới có hàng. Sản p...
# 201352  Thời gian giao hàng dài. Chất vải tạm ổn với g...
# 201353                               Cũng ổn nhìn hay hay
# 201354                  nhỏ xíu , ship 2 tuần , thất vọng
#
#                                          standard_comment  label
# 0       phù_hợp mua_nha nên_mua hàng_đẹp chắc_chắn sản...      1
# 1       đẹp_lắm rất_đẹp chắc_chắn đóng gói sản_phẩm và...      1
# 2       khá_xinh thiếu_hàng chất_lượng_quá_tuyệt_vời n...      1
# ...

# %% [markdown]
# # -1

# %%
sen_neg = " ".join(final_data[final_data['label'] == -1]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_neg)

# %% [markdown]
# # 0

# %%
sen_neu = " ".join(final_data[final_data['label'] == 0]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_neu)

# %% [markdown]
# # 1

# %%
sen_pos = " ".join(final_data[final_data['label'] == 1]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_pos)
