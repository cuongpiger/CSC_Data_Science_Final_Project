# %%
# %load_ext autoreload
# %autoreload 2

# %%
import modules.utils as Utils
import pandas as pd

# %%
final_data = pd.read_csv("./data/final_data.csv")

# %%
final_data
# Out:
#                                              raw_comment  \
# 0              Dép mang êm chân mẫu sang hàng chất lượng
# 1      Nón đẹp lắm ạ. Chất vải dày dặn, đường may đẹp...
# 2      Hơi mỏng tí, nhưng giao đúng mẫu, dthg cực é. ...
# 3      Kính rất đẹp, shop tư vấn nhiệt tình, trả lời ...
# 4      Tính  Tổng mét khối sdung\n=sumif( vùng dkien,...
# ...                                                  ...
# 34047  Sản phẩm giống hình. Chất liệu vải mềm.Giao hà...
# 34048  Ví bỏ thẻ vào thôi cũng hơi kích 1 chút nhưng ...
# 34049  Áo mặc khá ổn. Giao hàng nhanh đúng mẫu. Điểm ...
# 34050  Sản phẩm hơi mỏng nhưng mà vs giá sale 1000d v...
# 34051  Dây quá mỏng, không đang tiền, không nên mua, ...
#
#                                         standard_comment  label
# 0                              dép mang êm chân mẫu sang      1
# 1      nón vải dày_dặn chắc_chắn mặt thay_đổi tiện_lợ...      1
# 2                tí đúng mẫu cực é hộ hơi_mỏng giao_đúng      0
# 3      kính tư_vấn nhiệt_tình trả_lời tin nhắn nhanh ...      1
# 4      tính tổng mét_khối vùng vùng tính tổng nhớ bấm...      1
# ...                                                  ...    ...
# 34047          liệu vải mềm nhanh ổn đóng_gói giống_hình      0
# 34048                        ví bỏ thẻ hơi kích chút nỗi      1
# 34049  nhanh đúng mẫu điểm trừ túi bé túi ngực giao_h...      0
# 34050                              giá tốt hơi_mỏng sale      0
# 34051  dây mỏng đang tiền chưa dùng nên_mua không_nên...     -1
#
# [34052 rows x 3 columns]

# %% [markdown]
# # -1

# %%
sen_neg = " ".join(final_data[final_data['label'] == -1]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_neg)

# %% [markdown]
# # 0

# %%
sen_neu = " ".join(final_data[final_data['label'] == 0]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_neu)

# %% [markdown]
# # 1

# %%
sen_pos = " ".join(final_data[final_data['label'] == 1]['standard_comment'].to_list())

# %%
Utils.drawWordCloud(sen_pos)
